# %%
import numpy as np
import pandas as pd
from awesome_functions import *
import warnings
warnings.simplefilter('ignore')
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report , accuracy_score ,log_loss
from sklearn.ensemble import RandomForestClassifier , ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV , KFold
from sklearn.svm import SVC
import xgboost as xgb

# %% [markdown]
# ## 시행할 모델링을 선택해주세요 원하시지 않으면 `False` 로 처리해주세요

# %%
logistic = False
multi = False
random = False # 그리드서치로 인해 시간이 많이 소요됩니다.
extra = False # 그리드서치로 인해 시간이 많이 소요됩니다.
svc = False # 기본적으로 시간이 많이 소요됩니다.
xgboost = True

# %% [markdown]
# ## 경로를 포함한 파일이름을 넣어주시면 됩니다.

# %%
insert_training_file_name = 'Feature_matrix/new_df_dd_fl_cp_201808082113.csv' #here!!

# %% [markdown]
# ### 아래서부터는 건드시지 않으셔도 됩니다.

# %%
train_df = pd.read_csv(str(insert_training_file_name))

# %%
train_df.tail()
# Out:
#        VisitNumber  TripType  Return  1-HR PHOTO  ACCESSORIES  AUTOMOTIVE  \
# 95669       191343        25       0           0            0           0
# 95670       191344        22       0           0            0           0
# 95671       191345        39       0           0            0           0
# 95672       191346        39       0           0            0           0
# 95673       191347         8       0           0            0           0
#
#        BAKERY  BATH AND SHOWER  BEAUTY  BEDDING   ...    890104  890968  \
# 95669       0                0       0        0   ...         0       0
# 95670       0                0       4        0   ...         0       0
# 95671       0                0       1        0   ...         0       0
# 95672       0                0       0        0   ...         0       0
# 95673       0                0       0        0   ...         0       0
#
#        891038  891040  892992  893621  897522  897666  897752  898115
# 95669       0       0       0       0       0       0       0       0
# 95670       0       0       0       0       0       0       0       0
# 95671       0       0       0       0       0       0       0       0
# 95672       0       0       0       0       0       0       0       0
# 95673       0       0       0       0       0       0       0       0
#
# [5 rows x 1028 columns]

# %% [markdown]
# ## Split DataFrame into X , y

# %%
train_X , train_y = get_df_to_fit(train_df)

# %%
train_X.tail()
# Out:
#        Return  1-HR PHOTO  ACCESSORIES  AUTOMOTIVE  BAKERY  BATH AND SHOWER  \
# 95669       0           0            0           0       0                0
# 95670       0           0            0           0       0                0
# 95671       0           0            0           0       0                0
# 95672       0           0            0           0       0                0
# 95673       0           0            0           0       0                0
#
#        BEAUTY  BEDDING  BOOKS AND MAGAZINES  BOYS WEAR   ...    890104  \
# 95669       0        0                    0          0   ...         0
# 95670       4        0                    0          0   ...         0
# 95671       1        0                    0          0   ...         0
# 95672       0        0                    0          0   ...         0
# 95673       0        0                    0          0   ...         0
#
#        890968  891038  891040  892992  893621  897522  897666  897752  898115
# 95669       0       0       0       0       0       0       0       0       0
# 95670       0       0       0       0       0       0       0       0       0
# 95671       0       0       0       0       0       0       0       0       0
# 95672       0       0       0       0       0       0       0       0       0
# 95673       0       0       0       0       0       0       0       0       0
#
# [5 rows x 1026 columns]

# %%
train_y.tail()
# Out:
# 95669    25
# 95670    22
# 95671    39
# 95672    39
# 95673     8
# Name: TripType, dtype: int64

# %% [markdown]
# ## Logistic Regression
# - 시간이 좀 걸립니다.

# %%
if logistic:
    logis_model = LogisticRegression().fit(train_X , train_y)
    print("Logistic Regression's accuracy score: ",accuracy_score(train_y,logis_model.predict(train_X)))

# %% [markdown]
# ## Multinomial Naive Bayes
# - negative_value가 있으면 작동을 하지 않습니다.

# %%
if multi:
    Multi_model = MultinomialNB().fit(train_X,train_y)
    print("Multinomial Naive's accuracy score: ",accuracy_score(train_y,Multi_model.predict(train_X)))

# %% [markdown]
# ## Ensemble
# - Random forest, Extra Tree
# - 그리드 서치 이후, 값을 반환하기 때문에 시간이 소요됩니다.
# - n_jobs = -1 으로 설정되어 있기 때문에, 컴퓨터가 느려질 수 있습니다.

# %% [markdown]
# ## RandomForest

# %%
parameters = {'n_estimators':np.arange(1,100,10),'max_depth':np.arange(1,20,5)}
kfold = KFold(10)

# %%
if random:
    random_model = RandomForestClassifier(random_state=0)
    grid_model1 = GridSearchCV(random_model,parameters,scoring='accuracy',cv=kfold,n_jobs=-1)
    grid_model1.fit(train_X,train_y)
    params_ls1 = grid_model1.cv_results_['params']
    mean_test_score_ls1 = grid_model1.cv_results_["mean_test_score"]
    plt.plot(mean_test_score_ls1)
    print(grid_model1.best_score_)
    print(grid_model1.best_params_)

# %% [markdown]
# ## ExtraRandomForest

# %%
if extra:
    extra_model = ExtraTreesClassifier(random_state=0)
    grid_model2 = GridSearchCV(extra_model,parameters,scoring='accuracy',cv=kfold,n_jobs=-1)
    grid_model2.fit(train_X,train_y)
    params_ls2 = grid_model2.cv_results_['params']
    mean_test_score_ls2 = grid_model2.cv_results_["mean_test_score"]
    plt.plot(mean_test_score_ls2)
    print(grid_model2.best_score_)
    print(grid_model2.best_params_)

# %% [markdown]
# ## Support Vector Machine

# %%
if svc:
    svc_model = SVC(kernel='rbf',random_state=0).fit(train_X,train_y)
    print("Kernel Support Vector Machine's Accuracy score: ",\
          train_y,accuracy_score(svc_model.predict(train_X)))

# %% [markdown]
# ## Xgboost

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder().fit(train_y)
y_labeled = label_enc.transform(train_y)

# %%
train_X, test_X, train_y, test_y = train_test_split(train_X, y_labeled, random_state=0)

# %%
from scipy.sparse import csr_matrix

# %%
csr_train = csr_matrix(train_X.values)
csr_test = csr_matrix(test_X.values)

# %%
if xgboost:
    dtrain = xgb.DMatrix(csr_train, label=train_y)
    dtest = xgb.DMatrix(csr_test, label=test_y)
    num_boost_round = 300
    params = {'objective': 'multi:softprob', 
              'eval_metric': 'mlogloss',
              'num_class':38, 
              'max_delta_step': 3, 
              'eta': 0.2}

    evals = [(dtrain, 'train'), (dtest, 'eval')]

    bst = xgb.train(params=params,  
                    dtrain=dtrain, 
                    num_boost_round=num_boost_round, 
                    evals=evals,
                    early_stopping_rounds=10,)
# Out:
# [0]	train-mlogloss:3.06803	eval-mlogloss:3.07842
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:2.55732	eval-mlogloss:2.58119
# [2]	train-mlogloss:2.15374	eval-mlogloss:2.1919
# [3]	train-mlogloss:1.86139	eval-mlogloss:1.91069
# [4]	train-mlogloss:1.66514	eval-mlogloss:1.7227
# [5]	train-mlogloss:1.51844	eval-mlogloss:1.5833
# [6]	train-mlogloss:1.40253	eval-mlogloss:1.47421
# [7]	train-mlogloss:1.30999	eval-mlogloss:1.38792
# [8]	train-mlogloss:1.23242	eval-mlogloss:1.31628
# [9]	train-mlogloss:1.16779	eval-mlogloss:1.25694
# [10]	train-mlogloss:1.1137	eval-mlogloss:1.20726
# [11]	train-mlogloss:1.06687	eval-mlogloss:1.16523
# [12]	train-mlogloss:1.02598	eval-mlogloss:1.12903
# [13]	train-mlogloss:0.990832	eval-mlogloss:1.09806
# [14]	train-mlogloss:0.959172	eval-mlogloss:1.07073
# [15]	train-mlogloss:0.931729	eval-mlogloss:1.04704
# [16]	train-mlogloss:0.906866	eval-mlogloss:1.0261
# [17]	train-mlogloss:0.884681	eval-mlogloss:1.00747
# [18]	train-mlogloss:0.864233	eval-mlogloss:0.990701
# [19]	train-mlogloss:0.846288	eval-mlogloss:0.976085
# [20]	train-mlogloss:0.830084	eval-mlogloss:0.963441
# [21]	train-mlogloss:0.815175	eval-mlogloss:0.952314
# [22]	train-mlogloss:0.801437	eval-mlogloss:0.942189
# [23]	train-mlogloss:0.788398	eval-mlogloss:0.932343
# [24]	train-mlogloss:0.776027	eval-mlogloss:0.923357
# [25]	train-mlogloss:0.765071	eval-mlogloss:0.915635
# [26]	train-mlogloss:0.755389	eval-mlogloss:0.908931
# [27]	train-mlogloss:0.745468	eval-mlogloss:0.902282
# [28]	train-mlogloss:0.736994	eval-mlogloss:0.896725
# [29]	train-mlogloss:0.72791	eval-mlogloss:0.890759
# [30]	train-mlogloss:0.719544	eval-mlogloss:0.885437
# [31]	train-mlogloss:0.712366	eval-mlogloss:0.88099
# [32]	train-mlogloss:0.705043	eval-mlogloss:0.876495
# [33]	train-mlogloss:0.697697	eval-mlogloss:0.87253
# [34]	train-mlogloss:0.691615	eval-mlogloss:0.869224
# [35]	train-mlogloss:0.685596	eval-mlogloss:0.865799
# [36]	train-mlogloss:0.679986	eval-mlogloss:0.862714
# [37]	train-mlogloss:0.674426	eval-mlogloss:0.85962
# [38]	train-mlogloss:0.669185	eval-mlogloss:0.85715
# [39]	train-mlogloss:0.664103	eval-mlogloss:0.854726
# [40]	train-mlogloss:0.659232	eval-mlogloss:0.852606
# [41]	train-mlogloss:0.65463	eval-mlogloss:0.850391
# [42]	train-mlogloss:0.65006	eval-mlogloss:0.848411
# [43]	train-mlogloss:0.646015	eval-mlogloss:0.846326
# [44]	train-mlogloss:0.641986	eval-mlogloss:0.844232
# [45]	train-mlogloss:0.637825	eval-mlogloss:0.842693
# [46]	train-mlogloss:0.633913	eval-mlogloss:0.840909
# [47]	train-mlogloss:0.630301	eval-mlogloss:0.839366
# [48]	train-mlogloss:0.626678	eval-mlogloss:0.837714
# [49]	train-mlogloss:0.623313	eval-mlogloss:0.836302
# [50]	train-mlogloss:0.620003	eval-mlogloss:0.835205
# [51]	train-mlogloss:0.616889	eval-mlogloss:0.8338
# [52]	train-mlogloss:0.613697	eval-mlogloss:0.832571
# [53]	train-mlogloss:0.610812	eval-mlogloss:0.831681
# [54]	train-mlogloss:0.607684	eval-mlogloss:0.830617
# [55]	train-mlogloss:0.604901	eval-mlogloss:0.829435
# [56]	train-mlogloss:0.602042	eval-mlogloss:0.828303
# [57]	train-mlogloss:0.599233	eval-mlogloss:0.827317
# [58]	train-mlogloss:0.596483	eval-mlogloss:0.826507
# [59]	train-mlogloss:0.59377	eval-mlogloss:0.825705
# [60]	train-mlogloss:0.590845	eval-mlogloss:0.824908
# [61]	train-mlogloss:0.588381	eval-mlogloss:0.824069
# [62]	train-mlogloss:0.585876	eval-mlogloss:0.823313
# [63]	train-mlogloss:0.583502	eval-mlogloss:0.822538
# [64]	train-mlogloss:0.580899	eval-mlogloss:0.821797
# [65]	train-mlogloss:0.57841	eval-mlogloss:0.820801
# [66]	train-mlogloss:0.57649	eval-mlogloss:0.820234
# [67]	train-mlogloss:0.574051	eval-mlogloss:0.819346
# [68]	train-mlogloss:0.572006	eval-mlogloss:0.818602
# [69]	train-mlogloss:0.569812	eval-mlogloss:0.817909
# [70]	train-mlogloss:0.567598	eval-mlogloss:0.817282
# [71]	train-mlogloss:0.56535	eval-mlogloss:0.816411
# [72]	train-mlogloss:0.563134	eval-mlogloss:0.815679
# [73]	train-mlogloss:0.561216	eval-mlogloss:0.815293
# [74]	train-mlogloss:0.559141	eval-mlogloss:0.814789
# [75]	train-mlogloss:0.556965	eval-mlogloss:0.81415
# [76]	train-mlogloss:0.554786	eval-mlogloss:0.813555
# [77]	train-mlogloss:0.552758	eval-mlogloss:0.812999
# [78]	train-mlogloss:0.550866	eval-mlogloss:0.812512
# [79]	train-mlogloss:0.548721	eval-mlogloss:0.812041
# [80]	train-mlogloss:0.54682	eval-mlogloss:0.811619
# [81]	train-mlogloss:0.544796	eval-mlogloss:0.81109
# [82]	train-mlogloss:0.54316	eval-mlogloss:0.810754
# [83]	train-mlogloss:0.541272	eval-mlogloss:0.810266
# [84]	train-mlogloss:0.539577	eval-mlogloss:0.809938
# [85]	train-mlogloss:0.53797	eval-mlogloss:0.809757
# [86]	train-mlogloss:0.536205	eval-mlogloss:0.809306
# [87]	train-mlogloss:0.534558	eval-mlogloss:0.80883
# [88]	train-mlogloss:0.533085	eval-mlogloss:0.808521
# [89]	train-mlogloss:0.531356	eval-mlogloss:0.808248
# [90]	train-mlogloss:0.529887	eval-mlogloss:0.807934
# [91]	train-mlogloss:0.528092	eval-mlogloss:0.807594
# [92]	train-mlogloss:0.526396	eval-mlogloss:0.807243
# [93]	train-mlogloss:0.524757	eval-mlogloss:0.806923
# [94]	train-mlogloss:0.523253	eval-mlogloss:0.806573
# [95]	train-mlogloss:0.521705	eval-mlogloss:0.806075
# [96]	train-mlogloss:0.52038	eval-mlogloss:0.805817
# [97]	train-mlogloss:0.51901	eval-mlogloss:0.805554
# [98]	train-mlogloss:0.517436	eval-mlogloss:0.805323
# [99]	train-mlogloss:0.515969	eval-mlogloss:0.805166
# [100]	train-mlogloss:0.514541	eval-mlogloss:0.805147
# [101]	train-mlogloss:0.513047	eval-mlogloss:0.804971
# [102]	train-mlogloss:0.511775	eval-mlogloss:0.804821
# [103]	train-mlogloss:0.51045	eval-mlogloss:0.804501
# [104]	train-mlogloss:0.509049	eval-mlogloss:0.804103
# [105]	train-mlogloss:0.507735	eval-mlogloss:0.803858
# [106]	train-mlogloss:0.506471	eval-mlogloss:0.803582
# [107]	train-mlogloss:0.50499	eval-mlogloss:0.803354
# [108]	train-mlogloss:0.503716	eval-mlogloss:0.803016
# [109]	train-mlogloss:0.50232	eval-mlogloss:0.80279
# [110]	train-mlogloss:0.501139	eval-mlogloss:0.802674
# [111]	train-mlogloss:0.499722	eval-mlogloss:0.8024
# [112]	train-mlogloss:0.498369	eval-mlogloss:0.802343
# [113]	train-mlogloss:0.497206	eval-mlogloss:0.802204
# [114]	train-mlogloss:0.495968	eval-mlogloss:0.802081
# [115]	train-mlogloss:0.494702	eval-mlogloss:0.801826
# [116]	train-mlogloss:0.493394	eval-mlogloss:0.801538
# [117]	train-mlogloss:0.492065	eval-mlogloss:0.801499
# [118]	train-mlogloss:0.490782	eval-mlogloss:0.801353
# [119]	train-mlogloss:0.489444	eval-mlogloss:0.801135
# [120]	train-mlogloss:0.488204	eval-mlogloss:0.800841
# [121]	train-mlogloss:0.487002	eval-mlogloss:0.800658
# [122]	train-mlogloss:0.485808	eval-mlogloss:0.800571
# [123]	train-mlogloss:0.484697	eval-mlogloss:0.800323
# [124]	train-mlogloss:0.483397	eval-mlogloss:0.800052
# [125]	train-mlogloss:0.482225	eval-mlogloss:0.799898
# [126]	train-mlogloss:0.481109	eval-mlogloss:0.799814
# [127]	train-mlogloss:0.479948	eval-mlogloss:0.799595
# [128]	train-mlogloss:0.478837	eval-mlogloss:0.799501
# [129]	train-mlogloss:0.477711	eval-mlogloss:0.799338
# [130]	train-mlogloss:0.47675	eval-mlogloss:0.79922
# [131]	train-mlogloss:0.475746	eval-mlogloss:0.799025
# [132]	train-mlogloss:0.474747	eval-mlogloss:0.798945
# [133]	train-mlogloss:0.473356	eval-mlogloss:0.798649
# [134]	train-mlogloss:0.472286	eval-mlogloss:0.798462
# [135]	train-mlogloss:0.471087	eval-mlogloss:0.798325
# [136]	train-mlogloss:0.47005	eval-mlogloss:0.798263
# [137]	train-mlogloss:0.46889	eval-mlogloss:0.798084
# [138]	train-mlogloss:0.467812	eval-mlogloss:0.797967
# [139]	train-mlogloss:0.466677	eval-mlogloss:0.797973
# [140]	train-mlogloss:0.465679	eval-mlogloss:0.797861
# [141]	train-mlogloss:0.464721	eval-mlogloss:0.797766
# [142]	train-mlogloss:0.463725	eval-mlogloss:0.797728
# [143]	train-mlogloss:0.462769	eval-mlogloss:0.7976
# [144]	train-mlogloss:0.461773	eval-mlogloss:0.797491
# [145]	train-mlogloss:0.460683	eval-mlogloss:0.797439
# [146]	train-mlogloss:0.459629	eval-mlogloss:0.797405
# [147]	train-mlogloss:0.458693	eval-mlogloss:0.79723
# [148]	train-mlogloss:0.457775	eval-mlogloss:0.797045
# [149]	train-mlogloss:0.456833	eval-mlogloss:0.797016
# [150]	train-mlogloss:0.455954	eval-mlogloss:0.797028
# [151]	train-mlogloss:0.455023	eval-mlogloss:0.796911
# [152]	train-mlogloss:0.454007	eval-mlogloss:0.796683
# [153]	train-mlogloss:0.453011	eval-mlogloss:0.796662
# [154]	train-mlogloss:0.452224	eval-mlogloss:0.796669
# [155]	train-mlogloss:0.451366	eval-mlogloss:0.796663
# [156]	train-mlogloss:0.450428	eval-mlogloss:0.796558
# [157]	train-mlogloss:0.449588	eval-mlogloss:0.796488
# [158]	train-mlogloss:0.448776	eval-mlogloss:0.796462
# [159]	train-mlogloss:0.448018	eval-mlogloss:0.796429
# [160]	train-mlogloss:0.447087	eval-mlogloss:0.796431
# [161]	train-mlogloss:0.446224	eval-mlogloss:0.796244
# [162]	train-mlogloss:0.445412	eval-mlogloss:0.796102
# [163]	train-mlogloss:0.444595	eval-mlogloss:0.796053
# [164]	train-mlogloss:0.443726	eval-mlogloss:0.795957
# [165]	train-mlogloss:0.442794	eval-mlogloss:0.79589
# [166]	train-mlogloss:0.441947	eval-mlogloss:0.795888
# [167]	train-mlogloss:0.441129	eval-mlogloss:0.795821
# [168]	train-mlogloss:0.440264	eval-mlogloss:0.795685
# [169]	train-mlogloss:0.439437	eval-mlogloss:0.795729
# [170]	train-mlogloss:0.438606	eval-mlogloss:0.795583
# [171]	train-mlogloss:0.43777	eval-mlogloss:0.795496
# [172]	train-mlogloss:0.436915	eval-mlogloss:0.795431
# [173]	train-mlogloss:0.435996	eval-mlogloss:0.79551
# [174]	train-mlogloss:0.434956	eval-mlogloss:0.795473
# [175]	train-mlogloss:0.434054	eval-mlogloss:0.795423
# [176]	train-mlogloss:0.433159	eval-mlogloss:0.795485
# [177]	train-mlogloss:0.432398	eval-mlogloss:0.795443
# [178]	train-mlogloss:0.43167	eval-mlogloss:0.795439
# [179]	train-mlogloss:0.430904	eval-mlogloss:0.79532
# [180]	train-mlogloss:0.430164	eval-mlogloss:0.795284
# [181]	train-mlogloss:0.429328	eval-mlogloss:0.795268
# [182]	train-mlogloss:0.428524	eval-mlogloss:0.795201
# [183]	train-mlogloss:0.427792	eval-mlogloss:0.795226
# [184]	train-mlogloss:0.42694	eval-mlogloss:0.795216
# [185]	train-mlogloss:0.426073	eval-mlogloss:0.795129
# [186]	train-mlogloss:0.425304	eval-mlogloss:0.795216
# [187]	train-mlogloss:0.424439	eval-mlogloss:0.795161
# [188]	train-mlogloss:0.42364	eval-mlogloss:0.795114
# [189]	train-mlogloss:0.422905	eval-mlogloss:0.79517
# [190]	train-mlogloss:0.422172	eval-mlogloss:0.795095
# [191]	train-mlogloss:0.42143	eval-mlogloss:0.795028
# [192]	train-mlogloss:0.420674	eval-mlogloss:0.795035
# [193]	train-mlogloss:0.419871	eval-mlogloss:0.795045
# [194]	train-mlogloss:0.41909	eval-mlogloss:0.795032
# [195]	train-mlogloss:0.418213	eval-mlogloss:0.795066
# [196]	train-mlogloss:0.417432	eval-mlogloss:0.795116
# [197]	train-mlogloss:0.416663	eval-mlogloss:0.795199
# [198]	train-mlogloss:0.415894	eval-mlogloss:0.795335
# [199]	train-mlogloss:0.415225	eval-mlogloss:0.795339
# [200]	train-mlogloss:0.414395	eval-mlogloss:0.795403
# [201]	train-mlogloss:0.41374	eval-mlogloss:0.795466
# Stopping. Best iteration:
# [191]	train-mlogloss:0.42143	eval-mlogloss:0.795028

# %% [markdown]
# # dd와 fl 63개 그리고 scan total count(dd기준) 0.87
